# %% [markdown]
# - Deploy this google scrapping roadmap
# - https://dev.to/dmitryzub/scrape-google-organic-search-with-python-3hp5

# %%
import os, requests, json

from ecommercetools import seo

df = seo.get_serps("videos corporativos",domain="google.es",host_language="es")

list(df.title)

# %%
from ecommercetools import seo

results = seo.google_autocomplete("how to use chatgpt for a", include_expanded=False)

results

# print(suggestions)
#suggestions = seo.google_autocomplete("videos corporativos", include_expanded=True)
# Out:
#                                           term  relevance
# 0       how to use chat gpt for a cover letter       1250
# 1              how to use chatbot for a resume       1250
# 2   how to use chatgpt for affiliate marketing       1000
# 3      how to use chatbot for academic writing        751
# 4             how to use chat gpt for an essay        750
# 5       how to use chat gpt for a cover letter        604
# 6                   how to use chatbot for art        603
# 7                how to use chatbot for amazon        602
# 8       how to use chatbot for article writing        601
# 9                 what is export chat whatsapp        601
# 10               where is chat tab in whatsapp        601
# 11           how to use chat function in teams        601
# 12           how to use chat function in teams        601
# 13              how to use chat in google meet        601
# 14           how to use chat function in teams        601
# ...

# %%
import pandas as pd

results = seo.google_autocomplete("how to use chatgpt for a", include_expanded=False)
results
# Out:
#                                          term  relevance
# 0  how to use chatgpt for affiliate marketing       1000
# 1     how to use chatbot for academic writing        751
# 2            how to use chat gpt for an essay        750
# 3      how to use chat gpt for a cover letter        604
# 4                  how to use chatbot for art        603
# 5               how to use chatbot for amazon        602
# 6      how to use chatbot for article writing        601
# 7          how to use chatbot for assignments        600

# %%
# Scrapping Google´s suggestions
# https://dev.to/dmitryzub/scrape-google-autocomplete-suggestion-with-python-3cgb


import requests, json

headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}
# client param could be replaced with firefox or other browser
response = requests.get('http://google.es/complete/search?client=chrome&q="saas for a" software', headers=headers)
for result in json.loads(response.text)[1]:
    print(result)

# %%
import requests, lxml
from bs4 import BeautifulSoup


headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}

params = {
    "q": "apple",
    "hl": "en",
}

html = requests.get('http://google.es/complete/search?client=chrome&q=video marketing para')
soup = BeautifulSoup(html.text, 'lxml')

title = None
link = None
displayed_link = None
snippet = None


# container with all needed data
for result in soup.select('.tF2Cxc'):
    title = result.select_one('.LC20lb').text
    link = result.select_one('.yuRUbf a')['href']
    displayed_link = result.select_one('.TbwUpd.NJjxre').text
    snippet = result.select_one('#rso .lyLwlc').text
    break  # use break to only get the first search result

print("Title:", title)
print("Link:", link)
print("Displayed Link:", displayed_link)
print("Snippet:", snippet)


# inline sitelinks
for i in soup.select('.HiHjCd a'):
    print(i.text)

# expanded sitelinks
for t in soup.select('.usJj9c'):
    text = t.select_one('.r').text
    text_link = t.select_one('.r a')['href']
    snippet = t.select_one('.st').text

    print(f'{text}\n{text_link}\n{snippet}\n')

# %%
results = seo.get_serps("vídeos corporativos")

results.head()

list(results.title)

# %%
import pandas as pd

urls = ['https://practicaldatascience.co.uk/data-science/how-to-create-a-pandas-dataframe',
        'https://practicaldatascience.co.uk/data-science/how-to-query-the-google-search-console-api-with-ecommercetools',
        'https://practicaldatascience.co.uk/data-science/how-to-engineer-customer-purchase-latency-features',
        'https://practicaldatascience.co.uk/assets/files/marketing.pdf'
        ]
df = pd.DataFrame(list(zip(urls)), columns=['loc'])
df_pages = seo.scraping.scrape_site(df)

df_pages

list(df_pages.description)
